# %% [markdown]
# # Error Analysis
#
# This notebook is a lightweight placeholder for inspecting false positives, false negatives, and subgroup slices.

# %%
import pandas as pd

preds = pd.read_csv('../data/processed/test_predictions.csv')
preds.head()
