# %% [markdown]
# # Data Understanding
#
# This notebook is a lightweight placeholder for exploring the generated synthetic AMR-like dataset.

# %%
import pandas as pd

df = pd.read_csv('../data/raw/synthetic_amr.csv')
df.head()
