# %% [markdown]
# # Modeling Baseline
#
# This notebook is a lightweight placeholder for reviewing the baseline training pipeline.

# %%
from src.training.train import train_model

# Run from project root in a notebook environment:
# train_model()
